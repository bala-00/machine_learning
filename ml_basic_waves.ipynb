# %%
import cmath
import matplotlib.pyplot as plt
x=[]
y=[]
j=0.0
for i in range(100):
    x.append(j)
    y.append(math.cos(j))
    j=j+.1
plt.plot(x,y)
plt.show()

# %%
# !pip install matplotlib

# %%
import cmath
import matplotlib.pyplot as plt
x=[]
y=[]

def fact(x):
    if(x==0 or x==1):
        return 1
    else:
        return(x*fact(x-1))
def sin(x):
    sin=0
    j=1
for i in range(100):
    k=x**j/fact(j)
    j=j+2
    if(i%2==0):
        sin=sin+k
    else:
        sin=sin-k
return sin
j=0.0
for i in range(100):
    x.append(i)
    y.append(math.sin(j))
    j=j+.1
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25488\60477508.py in <module>
#      13     j=1
#      14 for i in range(100):
# ---> 15     k=x**j/fact(j)
#      16     j=j+2
#      17     if(i%2==0):
#
# NameError: name 'j' is not defined

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,6,5,5,5,4]
plt.hist(x,bins=[1,3,5,7])
plt.show()

# %%
import scipy.stats
import statistics as s
a=[[6,7,3,8],[5,5,3,7],[5,4,3,4]]
x1=s.mean(a[0])
x2=s.mean(a[1])
x3=s.mean(a[2])
m=[x1,x2,x3]
print(m)
x11=s.mean(m)
print(x11)
ssb=0
ssw=0
msb=0
msw=0
for i in range(3):
    ssb+=(4*((m[i]-x11)**2))
print("ssb",ssb)    
msb=ssb/2
print("msb",msb)
for i in range(3):
    for j in range(4):
        ssw+=(((a[i][j]-m[i])**2))
print("ssw",ssw)
msw=ssw/9
print("msw",msw)
f=msb/msw
print("f",f)
e=scipy.stats.f.ppf(.95,2,9)
print("e",e)
# Out:
# C:\Users\Public\anaapp\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [6, 5, 4]
# 5
# ssb 8
# msb 4.0
# ssw 24
# msw 2.6666666666666665
# f 1.5
# e 4.25649472909375

# %%
import scipy.stats
import statistics as s
a=[[6,5,5],[7,5,4],[3,3,3],[8,7,4]]
R=[]
C=[]
t=0
ti=0
c=0
g=0
e=0
tin=0
for i in range(4):
    for j in range(3):
        t=t+a[i][j]
print("T",t)
W=t**2/12
print("W",W)
for i in a:
    for j in i:
        e=e+(j**2)        
print(e)
tss=e-W
print("tss",tss)
for i in range(4):
    s=0
    for j in range(3):
        s=s+a[i][j]
    R.append(s)  
print(R)    
for j in range(3):    
    ss=0
    for i in range(4):
        ss=ss+a[i][j]
    C.append(ss)  
print(C)    
for i in R:
    tin=tin+((i**2)/3)
print(tin)     
for i in C:
    ti=ti+((i**2)/4)
print(ti)  
ew=scipy.stats.f.ppf(.95,2,6)
print(ew)
ev=scipy.stats.f.ppf(.95,3,6)
print(ev)
# Out:
# T 60
# W 300.0
# 332
# tss 32.0
# [16, 16, 9, 19]
# [24, 20, 16]
# 318.0
# 308.0
# 5.143252849784718
# 4.757062663089414

# %%
def mul(a):
    a=int(input("enter the num"))
    for i in range(1,11):
        print(a,"*",i,"=",i*a)
mul(a)
# Out:
# enter the num10
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100

# %%
s=input("enter")
print(s)
r=input("enter replace")
w=input("enter")
s=s.replace(r,w)
print(s)
# Out:
# enterhai hey hoi
# hai hey hoi
# enter replacehoi
# enterhey
# hai hey hey

# %%
import numpy as np
r=3
i=0
j=0
c=3
a=[[0 for i in range(c)]for j in range(r)]
b=[[0 for i in range(c)]for j in range(r)]
cn=[[0 for i in range(c)]for j in range(r)]
for i in range(r):
    for j in range(c):
        a[i][j]=int(input())
for i in range(r):
    for j in range(c):
        b[i][j]=int(input())  
cn=np.dot(a,b)        
for i in range(r):
    for j in range(c):
        print(cn[i][j],end" ")
        print("\t")
    print("\n")
# Out:
# 1
# 7
# 3
# 3
# 5
# 6
# 6
# 8
# 9
# 1
# 0
# 0
# 0
# 1
# 0
# 0
# 0
# 1
# 1
#
# 7
#
# 3
#
#
#
# 3
#
# 5
#
# 6
#
#
#
# 6
#
# 8
#
# 9

# %%
9
1

# %%
 
def add (dict):
    k=input("enter the title\n")
    m=int(input("enter the no.\n"))
    if k in dict:
        print("exist")
    else:
        dict[k]=m
def rem(dict):
    w=input("enter the title")
    if w in dict:
        dict.pop(k)
    else:
        print("not present")
def update(dict):
    k=input("enter the title")
    if k in dict:
        l=int(input("enter the new"))
        dict[k]+=n
    else:
        print("not present")
dict={}
n=1
while(n):
    print("MENU\n 1.add\n2.rem\n3.update\n")
    b=int(input("enter the choice\n"))
    if(b==1):
        add(dict)
    elif(b==2):
        rem(dict)
    elif(b==3):
        up(dict)
    else:
        n=0
print(dict)
# Out:
# MENU
#  1.add
# 2.rem
# 3.update
#
# enter the choice
# 1
# enter the title
# adam
# enter the no.
# 5
# MENU
#  1.add
# 2.rem
# 3.update
#
# enter the choice
# 1
# enter the title
# eve
# enter the no.
# 5
# MENU
#  1.add
# 2.rem
# 3.update
#
# enter the choice
# 4
# {'adam': 5, 'eve': 5}

# %%
import matplotlib.pyplot as plt
x=[]
y=[]
for i in range(5):
    xp=int(input("enter the num"))
    yp=xp**3
    x.append(xp)
    y.append(yp)
plt.plot(x,y)
plt.show()
# Out:
# enter the num1
# enter the num2
# enter the num3
# enter the num4
# enter the num5

# %%
import matplotlib.pyplot as plt
import cmath as m
x=[]
y=[]
j=0.0
for i in range(100):
    x.append(j)
    y.append(m.sin(j))
    j=j+.1
plt.plot(x,y)
plt.show()
